# %% [markdown]
# ## Install TDW

# %%
# !pip install tdw
# Out:
# Requirement already satisfied: tdw in c:\users\aryan\anaconda3\envs\cbmm_tutorial\lib\site-packages (1.12.18.0)
# Requirement already satisfied: pyzmq in c:\users\aryan\anaconda3\envs\cbmm_tutorial\lib\site-packages (from tdw) (26.0.3)
# Requirement already satisfied: numpy in c:\users\aryan\anaconda3\envs\cbmm_tutorial\lib\site-packages (from tdw) (2.0.1)
# Requirement already satisfied: scipy in c:\users\aryan\anaconda3\envs\cbmm_tutorial\lib\site-packages (from tdw) (1.14.0)
# Requirement already satisfied: pillow in c:\users\aryan\anaconda3\envs\cbmm_tutorial\lib\site-packages (from tdw) (10.4.0)
# Requirement already satisfied: tqdm in c:\users\aryan\anaconda3\envs\cbmm_tutorial\lib\site-packages (from tdw) (4.66.4)
# Requirement already satisfied: psutil in c:\users\aryan\anaconda3\envs\cbmm_tutorial\lib\site-packages (from tdw) (6.0.0)
# Requirement already satisfied: boto3 in c:\users\aryan\anaconda3\envs\cbmm_tutorial\lib\site-packages (from tdw) (1.34.151)
# Requirement already satisfied: botocore in c:\users\aryan\anaconda3\envs\cbmm_tutorial\lib\site-packages (from tdw) (1.34.151)
# Requirement already satisfied: requests in c:\users\aryan\anaconda3\envs\cbmm_tutorial\lib\site-packages (from tdw) (2.32.3)
# Requirement already satisfied: pyinstaller in c:\users\aryan\anaconda3\envs\cbmm_tutorial\lib\site-packages (from tdw) (6.9.0)
# Requirement already satisfied: overrides in c:\users\aryan\anaconda3\envs\cbmm_tutorial\lib\site-packages (from tdw) (7.7.0)
# Requirement already satisfied: packaging in c:\users\aryan\anaconda3\envs\cbmm_tutorial\lib\site-packages (from tdw) (24.1)
# Requirement already satisfied: pydub in c:\users\aryan\anaconda3\envs\cbmm_tutorial\lib\site-packages (from tdw) (0.25.1)
# Requirement already satisfied: ikpy==3.1 in c:\users\aryan\anaconda3\envs\cbmm_tutorial\lib\site-packages (from tdw) (3.1)
# Requirement already satisfied: screeninfo in c:\users\aryan\anaconda3\envs\cbmm_tutorial\lib\site-packages (from tdw) (0.8.1)
# Requirement already satisfied: sympy in c:\users\aryan\anaconda3\envs\cbmm_tutorial\lib\site-packages (from ikpy==3.1->tdw) (1.13.1)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\aryan\anaconda3\envs\cbmm_tutorial\lib\site-packages (from boto3->tdw) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in c:\users\aryan\anaconda3\envs\cbmm_tutorial\lib\site-packages (from boto3->tdw) (0.10.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\aryan\anaconda3\envs\cbmm_tutorial\lib\site-packages (from botocore->tdw) (2.9.0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in c:\users\aryan\anaconda3\envs\cbmm_tutorial\lib\site-packages (from botocore->tdw) (2.2.2)
# Requirement already satisfied: setuptools>=42.0.0 in c:\users\aryan\anaconda3\envs\cbmm_tutorial\lib\site-packages (from pyinstaller->tdw) (71.0.4)
# Requirement already satisfied: altgraph in c:\users\aryan\anaconda3\envs\cbmm_tutorial\lib\site-packages (from pyinstaller->tdw) (0.17.4)
# Requirement already satisfied: pyinstaller-hooks-contrib>=2024.7 in c:\users\aryan\anaconda3\envs\cbmm_tutorial\lib\site-packages (from pyinstaller->tdw) (2024.7)
# Requirement already satisfied: pefile>=2022.5.30 in c:\users\aryan\anaconda3\envs\cbmm_tutorial\lib\site-packages (from pyinstaller->tdw) (2023.2.7)
# Requirement already satisfied: pywin32-ctypes>=0.2.1 in c:\users\aryan\anaconda3\envs\cbmm_tutorial\lib\site-packages (from pyinstaller->tdw) (0.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\aryan\anaconda3\envs\cbmm_tutorial\lib\site-packages (from requests->tdw) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aryan\anaconda3\envs\cbmm_tutorial\lib\site-packages (from requests->tdw) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aryan\anaconda3\envs\cbmm_tutorial\lib\site-packages (from requests->tdw) (2024.7.4)
# Requirement already satisfied: colorama in c:\users\aryan\anaconda3\envs\cbmm_tutorial\lib\site-packages (from tqdm->tdw) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\aryan\anaconda3\envs\cbmm_tutorial\lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore->tdw) (1.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\aryan\anaconda3\envs\cbmm_tutorial\lib\site-packages (from sympy->ikpy==3.1->tdw) (1.3.0)

# %% [markdown]
# ## Import Packages

# %%
from tdw.controller import Controller
from tdw.add_ons.oculus_touch import OculusTouch
from tdw.output_data import OutputData
from tdw.add_ons.third_person_camera import ThirdPersonCamera
from tdw.tdw_utils import TDWUtils
from tdw.librarian import ModelLibrarian
from tdw.output_data import OutputData, Bounds
from scipy.spatial.transform import Rotation as R
from tdw.add_ons.image_capture import ImageCapture
from tdw.librarian import ModelLibrarian
import numpy as np
import os
import time

# %% [markdown]
# ## Create Libraries/Folder to save recorded files
# IMPORTANT: If you are using Mac, replace "Windows" with "Darwin" in the 6th line and if you are using Linux, replace it with "Linux"

# %%
current_dir = os.path.dirname(os.getcwd())
if os.path.exists(os.path.join(current_dir, "assets")):
    local_librarian = ModelLibrarian(
        library=os.path.join(current_dir, "assets", "library.json")
    )
    models_directory = (
        os.path.join(current_dir, "assets", "Windows").replace("\\", "/") + "/"
    )
else:
    print("No local models found")
    models_directory = None
    local_librarian = None

images_dir = os.path.join(current_dir, "images")
if not os.path.exists(images_dir):
    os.makedirs(images_dir)

videos_dir = os.path.join(current_dir, "videos")
if not os.path.exists(videos_dir):
    os.makedirs(videos_dir)
# Out:
# No local models found

# %% [markdown]
# ## Helper functions

# %%
def get_bounds(c, obj_id, rotation):
    resp = c.communicate({"$type": "send_bounds", "frequency": "once"})
    for i in range(len(resp) - 1):
        r_id = OutputData.get_data_type_id(resp[i])
        if r_id == "boun":
            bounds = Bounds(resp[i])
            for j in range(bounds.get_num()):
                if bounds.get_id(j) == obj_id:
                    top = bounds.get_top(j)[1]
                    bottom = bounds.get_bottom(j)[1]
                    back = bounds.get_back(j)[2]
                    front = bounds.get_front(j)[2]
                    left = bounds.get_left(j)[0]
                    right = bounds.get_right(j)[0]
    init_corners = np.array(
        [
            [left, top, back],
            [left, top, front],
            [left, bottom, back],
            [left, bottom, front],
            [right, top, back],
            [right, top, front],
            [right, bottom, back],
            [right, bottom, front],
        ]
    )

    r = (
        R.from_euler(
            "xyz", [[rotation["x"], rotation["y"], rotation["z"]]], degrees=True
        )
        .as_matrix()
        .squeeze()
    )

    transformed_corners = np.matmul(r, init_corners.T).T

    return {
        "left": float(left),
        "right": float(right),
        "top": float(top),
        "bottom": float(bottom),
        "front": float(front),
        "back": float(back),
        "width": abs(float(left - right)),
        "height": abs(float(top - bottom)),
        "depth": abs(float(front - back)),
        "corners": transformed_corners.tolist(),
    }


def add_your_own_object(
    c,
    name,
    id,
    position,
    rotation={"x": 0, "y": 0, "z": 0},
    mass=5,
    color=None,
    scale={"x": 1, "y": 1, "z": 1},
    material=None,
    dynamic_friction=0.3,
    static_friction=0.3,
    bounciness=0.7,
    set_kinematic=False,
    use_gravity=True
):
    commands = []
    commands.extend(
        [
            {
                "$type": "add_object",
                "name": name,
                "url": "file:///" + models_directory + name,
                "id": id,
                "position": position,
            },
            {
                "$type": "scale_object",
                "scale_factor": scale,
                "id": id,
            },
        ]
    )
    if material:
        model_record = local_librarian.get_record(name)
        commands.extend(
            TDWUtils.set_visual_material(
                c=c,
                substructure=model_record.substructure,
                material=material,
                object_id=id,
            )
        )
    commands.append({"$type": "set_mass", "mass": mass, "id": id})
    commands.extend(
        [
            {
                "$type": "rotate_object_by",
                "angle": rotation["x"],
                "id": id,
                "axis": "pitch",
                "use_centroid": True,
            },
            {
                "$type": "rotate_object_by",
                "angle": rotation["y"],
                "id": id,
                "axis": "yaw",
                "use_centroid": True,
            },
            {
                "$type": "rotate_object_by",
                "angle": rotation["z"],
                "id": id,
                "axis": "roll",
                "use_centroid": True,
            },
        ]
    )

    commands.extend(
        [
            {
                "$type": "set_kinematic_state",
                "id": id, 
                "is_kinematic": set_kinematic, 
                "use_gravity": use_gravity
            },
            {
                "$type": "set_physic_material",
                "dynamic_friction": dynamic_friction, 
                "static_friction": static_friction, 
                "bounciness": bounciness, 
                "id": id
            }
        ]
    )

    if color:
        commands.append({"$type": "set_color", "color": color, "id": id})
    c.communicate(commands)
    bounds = get_bounds(c, id, rotation)
    c.communicate([])

    return bounds

def add_tdw_object(
    c,
    name,
    id,
    position,
    rotation={"x": 0, "y": 0, "z": 0},
    mass=5,
    color=None,
    scale={"x": 1, "y": 1, "z": 1},
    material=None,
    dynamic_friction=0.3,
    static_friction=0.3,
    bounciness=0.7,
    set_kinematic=False,
    use_gravity=True,
    library="models_core.json"
):
    commands = []
    commands.extend(
        c.get_add_physics_object(
            model_name=name,
            object_id=id,
            position=position,
            rotation=rotation,
            mass=mass,
            default_physics_values = False,
            dynamic_friction=dynamic_friction,
            static_friction=static_friction,
            bounciness=bounciness,
            gravity=use_gravity,
            kinematic=set_kinematic,
            scale_factor=scale,
            library=library
        )
    )

    if color:
        commands.append({"$type": "set_color", "color": color, "id": id})

    if material:
        librarian = ModelLibrarian(library=library)
        model_record = librarian.get_record(name)
        commands.extend(
            TDWUtils.set_visual_material(
                c=c,
                substructure=model_record.substructure,
                material=material,
                object_id=id,
            )
        )

    c.communicate(commands)
    bounds = get_bounds(c, id, rotation)
    
    return bounds

# %% [markdown]
# ## Controller
# A controller is the Python object that communicates with the simulation application (the build). You can code up your scene in the controller and send it to the simulator for rendering. Similarly, the simulator sends the output data (including pose of every object and agent, collisions, RGB and depth maps, etc) back to the controller and you can read them out.

# %%
c = Controller(launch_build=False)
# Out:
# You are using TDW 1.12.18.0 but version 1.13.0.0 is available.
# Consider upgrading:
# pip3 install tdw -U
# Build version 1.12.18
# Unity Engine 2020.3.24f1
# Python tdw module version 1.12.18.0

# %% [markdown]
# ## Create a scene
# You need a room where stuff happen in. Here we use one of the many rooms that exist in TDW. To see other rooms, take a look at:
#
# https://github.com/threedworld-mit/tdw/blob/master/Documentation/lessons/core_concepts/scenes.md
#
# This step is going to take some time to run....

# %%
c.communicate(c.get_add_scene(scene_name="tdw_room"))
c.communicate(
    [
        TDWUtils.create_empty_room(15, 15),
        {"$type": "set_screen_size", "width": 1000, "height": 1000},
        {"$type": "set_target_framerate", "framerate": 60},
    ]
)
# Out:
# [b'\x00\x00\x00\x03']

# %% [markdown]
# You may wonder why you don't see anything. That's because you need a camera to act as your eyes:

# %%
camera_1 = ThirdPersonCamera(avatar_id="a",
                           position={"x": 0, "y": 1.6, "z": -1.0},
                           rotation={"x": 0, "y": 0, "z": 0},
                           field_of_view=105
)
c.add_ons.append(camera_1)
c.communicate([])
# Out:
# [b'\x00\x00\x00\x04']

# %% [markdown]
# Now it's time to add objects. TDW has thousands of existing objects in three libraries. You can use the command below to see a list of all existing objects:

# %%
libraries = ["models_core.json", "models_special.json", "models_flex.json"]
for library in libraries:
    librarian = ModelLibrarian(library)
    for record in librarian.records:
        print(library, record.name)
# Out:
# models_core.json 034_vray
# models_core.json 102_pepsi_can_12_fl_oz_vray
# models_core.json 104_sprite_can_12_fl_oz_vray
# models_core.json 12_06_001
# models_core.json 24_in_wall_cabinet_white_wood
# models_core.json 24_in_wall_cabinet_wood_beach_honey
# models_core.json 36_in_wall_cabinet_white_wood
# models_core.json 36_in_wall_cabinet_wood_beach_honey
# models_core.json 4ft_shelf_metal
# models_core.json 4ft_wood_shelving
# models_core.json 5ft_shelf_metal
# models_core.json 5ft_wood_shelving
# models_core.json 699264_shoppingcart_2013
# models_core.json 6ft_shelf_metal
# models_core.json 6ft_wood_shelving
# models_core.json 868580_pliers_max2016
# models_core.json 9v_battery
# models_core.json aaa_battery
# models_core.json afl_lamp
# models_core.json alarm_clock
# models_core.json alivar_tech_bench_sofa
# models_core.json alma_floor_lamp
# models_core.json amphora_jar_vase
# models_core.json apple
# models_core.json apple_ipod_touch_grey_vray
# models_core.json apple_ipod_touch_pink_vray
# models_core.json apple_ipod_touch_yellow_vray
# models_core.json appliance-ge-profile-microwave
# models_core.json appliance-ge-profile-microwave3
# models_core.json appliance-ge-profile-microwave3_composite
# models_core.json appliance-ge-profile-microwave_composite
# models_core.json aquostv
# models_core.json arco_lamp
# models_core.json arflex_hollywood_sofa
# models_core.json arflex_strips_sofa
# models_core.json arturoalvarez_v_floor_lamp
# models_core.json atmosphere_nodo
# models_core.json b01_bag
# models_core.json b01_spatula
# models_core.json b01_trumpet
# models_core.json b02_bag
# models_core.json b03_696615_object001
# models_core.json b03_aluminum_pan
# models_core.json b03_aluminum_pan_composite
# models_core.json b03_backpack
# models_core.json b03_banana_01_high
# models_core.json b03_basket
# models_core.json b03_beats_solo_hd_headphone_03_2010
# models_core.json b03_bosch_cbg675bs1b_2013__vray_composite
# models_core.json b03_burger
# models_core.json b03_cocacola_can_cage
# models_core.json b03_cooking_pot_01
# models_core.json b03_cooking_pot_01_composite
# models_core.json b03_db_apps_tech_08_04_composite
# models_core.json b03_db_apps_tech_08_07_composite
# models_core.json b03_db_apps_tech_08_08_composite
# models_core.json b03_dollarstack
# models_core.json b03_hair_comb_2010
# models_core.json b03_iron_candle_vray
# models_core.json b03_ka90ivi20r_2013__vray
# models_core.json b03_ka90ivi20r_2013__vray_composite
# models_core.json b03_loafbread
# models_core.json b03_morphy_2013__vray
# models_core.json b03_object05
# models_core.json b03_old_scissors
# models_core.json b03_padlock
# models_core.json b03_pen
# models_core.json b03_pen_01_001
# models_core.json b03_piccolo_trumpet_vray
# models_core.json b03_pot
# models_core.json b03_radiator_alum_12
# models_core.json b03_restoration_hardware_pedestal_salvaged_round_tables
# models_core.json b03_roller_skate
# models_core.json b03_shopping_cart
# models_core.json b03_shopping_cart_walmart
# models_core.json b03_shoppingcart_2013
# models_core.json b03_spoon_001
# models_core.json b03_toothbrush
# models_core.json b03_trumpet_vray
# models_core.json b04_03_077
# models_core.json b04_1106_backpack
# models_core.json b04_11_02_041
# models_core.json b04_3d_jar_180_gr_01
# models_core.json b04_armani_handbag
# models_core.json b04_b200003_01
# models_core.json b04_backpack
# models_core.json b04_banana
# models_core.json b04_baseball_bat
# models_core.json b04_basket
# models_core.json b04_baterijska_busilica
# models_core.json b04_bottle-2014-2018
# models_core.json b04_bottle_20ml
# models_core.json b04_bottle_2_max
# models_core.json b04_bottle_max
# models_core.json b04_bowl_smooth
# models_core.json b04_can
# models_core.json b04_candle_holder_metal
# models_core.json b04_cantate_crystal_wine_glass
# models_core.json b04_cassete
# models_core.json b04_cgaxis_models_31_12_vray
# models_core.json b04_champions_trophy
# models_core.json b04_comb
# models_core.json b04_dat
# models_core.json b04_db_apps_tech_08_03
# models_core.json b04_db_apps_tech_08_03_composite
# models_core.json b04_default
# models_core.json b04_dump
# models_core.json b04_faucet1
# models_core.json b04_fireextinguisher
# models_core.json b04_geosphere001
# models_core.json b04_glass_06_vray
# models_core.json b04_headphones_31_12
# models_core.json b04_honey_jar
# models_core.json b04_honey_jar_max_2014
# models_core.json b04_kevin_reilly_pattern_floor_lamp
# models_core.json b04_lighter
# models_core.json b04_low
# models_core.json b04_money
# models_core.json b04_new
# models_core.json b04_orange_00
# models_core.json b04_p22732_cc_cp_2013
# models_core.json b04_p25050_slc_ad_2013
# models_core.json b04_ramlosa_bottle_2015_vray
# models_core.json b04_roller_new
# models_core.json b04_scissors_2013
# models_core.json b04_screwdriver_render
# models_core.json b04_screwdriver_v2_texture_
# models_core.json b04_shoppping_cart
# models_core.json b04_wallmounted_soap_dispenser_composite
# models_core.json b04_whiskeybottle
# models_core.json b04_wineglass
# models_core.json b04_wire_pincers
# models_core.json b05_48_body_shop_hair_brush
# models_core.json b05_ball-point_pen-obj
# models_core.json b05_bathroom_dispenser
# models_core.json b05_beko_oie_22500x_2013__corona
# models_core.json b05_calculator
# models_core.json b05_candles_max_vray2
# models_core.json b05_candlestick_with_candles002_max2017_vray
# models_core.json b05_castironradiator
# models_core.json b05_cgaxis_models_37_17_vray
# models_core.json b05_champagne_cup_vray
# models_core.json b05_coffee_grinder
# models_core.json b05_cylinder001
# models_core.json b05_dacor_double_wall_oven
# models_core.json b05_db_apps_tech_06_02_2
# models_core.json b05_db_apps_tech_08_09
# models_core.json b05_db_apps_tech_08_09_composite
# models_core.json b05_delonghi_icona_toaster
# models_core.json b05_executive_pen
# models_core.json b05_fire_extinguisher
# models_core.json b05_gold_glass_soap_dispenser(max)
# models_core.json b05_ikea_nutid_side_by_side_refrigerator
# models_core.json b05_max2013vray_oven_by_whirlpool_akzm8910ixl
# models_core.json b05_p24409_00_cp_2013
# models_core.json b05_racket
# models_core.json b05_shopping_cart3
# models_core.json b05_snickers
# models_core.json b05_sugerjar_a001_2015
# models_core.json b05_table_new
# models_core.json b05_tag_heuer_max2014
# models_core.json b05_vray_cassette_render_scene
# models_core.json b05_whirlpool_microwave_wmc30516as_v-ray
# models_core.json b06_21_dualit_original_toaster_4x
# models_core.json b06_backpack
# models_core.json b06_backpack_new
# models_core.json b06_circle
# models_core.json backpack
# models_core.json bag_14
# models_core.json bag_3
# models_core.json bakerparisfloorlamp03
# models_core.json baking_sheet01
# models_core.json baking_sheet02
# models_core.json baking_sheet03
# models_core.json baking_sheet04
# models_core.json baking_sheet05
# models_core.json baking_sheet06
# models_core.json baking_sheet07
# models_core.json baking_sheet08
# models_core.json baking_sheet09
# models_core.json baking_sheet10
# models_core.json balance_double_doghouse
# models_core.json baleri_italia_folded_black_table
# models_core.json ball_peen_hammer
# models_core.json banana_fix2
# models_core.json barcelona_bench_sofa
# models_core.json basic_cork
# models_core.json basic_cork_2
# models_core.json basket_18inx18inx12iin
# models_core.json basket_18inx18inx12iin_bamboo
# models_core.json basket_18inx18inx12iin_plastic_lattice
# models_core.json basket_18inx18inx12iin_wicker
# models_core.json basket_18inx18inx12iin_wood_mesh
# models_core.json bastone_floor_lamp
# models_core.json baton_table_lamp_dark
# models_core.json bed01
# models_core.json bed01_blue
# models_core.json bed01_red
# models_core.json bee
# models_core.json bench
# models_core.json black_lamp
# models_core.json blue_bag
# models_core.json blue_club_chair
# models_core.json blue_edition_liquid_soap02
# models_core.json blue_rug
# models_core.json blue_satchal
# models_core.json blue_side_chair
# models_core.json bookend01
# models_core.json bookend03
# models_core.json bookend04
# models_core.json bookend05
# models_core.json bookend06
# models_core.json bookend07
# models_core.json bork_vacuum
# models_core.json bow_rake
# models_core.json box_18inx18inx12in_cardboard
# models_core.json box_24inx18inx12in_cherry
# models_core.json box_tapered_beech
# models_core.json box_tapered_white_mesh
# models_core.json bread
# models_core.json brizo_solna
# models_core.json bronze_purse
# models_core.json brown_leather_dining_chair
# models_core.json brown_leather_side_chair
# models_core.json buddah
# models_core.json bung
# models_core.json button_four_hole_large_black
# models_core.json button_four_hole_large_wood
# models_core.json button_four_hole_mottled
# models_core.json button_four_hole_red_plastic
# models_core.json button_four_hole_white_plastic
# models_core.json button_four_hole_wood
# models_core.json button_two_hole_green_mottled
# models_core.json button_two_hole_grey
# models_core.json button_two_hole_red_mottled
# models_core.json button_two_hole_red_wood
# models_core.json cabinet_24_door_drawer_wood_beach_honey
# models_core.json cabinet_24_single_door_wood_beech_honey_composite
# models_core.json cabinet_24_single_door_wood_oak_white_composite
# models_core.json cabinet_24_singledoor_wood_beach_honey
# models_core.json cabinet_24_two_door_wood_beech_honey_composite
# models_core.json cabinet_24_two_door_wood_oak_white_composite
# models_core.json cabinet_24_two_drawer_white_wood
# models_core.json cabinet_24_two_drawer_wood_beach_honey
# models_core.json cabinet_24_wall_wood_beech_honey_composite
# models_core.json cabinet_24_wall_wood_oak_white_composite
# models_core.json cabinet_24_white_wood
# models_core.json cabinet_24_wood_beach_honey
# models_core.json cabinet_36_two_door_wood_beech_honey_composite
# models_core.json cabinet_36_two_door_wood_oak_white_composite
# models_core.json cabinet_36_wall_wood_beech_honey_composite
# models_core.json cabinet_36_wall_wood_oak_white_composite
# models_core.json cabinet_36_white_wood
# models_core.json cabinet_36_wood_beach_honey
# models_core.json cabinet_full_height_white_wood
# models_core.json cabinet_full_height_wood_beach_honey
# models_core.json cabinet_full_height_wood_beech_honey_composite
# models_core.json cabinet_full_height_wood_oak_white_composite
# models_core.json cafe_2010
# models_core.json calculator
# models_core.json camera_box
# models_core.json candle
# models_core.json candles_max_vray
# models_core.json candlestick1
# models_core.json carpet_rug
# models_core.json cerno_lamp
# models_core.json cgaxis_models_10_11_vray
# models_core.json cgaxis_models_20_05_vray
# models_core.json cgaxis_models_23_19_vray
# models_core.json cgaxis_models_37_15_vray
# models_core.json cgaxis_models_50_12_vray
# models_core.json cgaxis_models_50_24_vray
# models_core.json cgaxis_models_61_17_vray
# models_core.json cgaxis_models_65_06_vray
# models_core.json cgaxis_models_65_14_vray
# models_core.json cgaxis_models_volume_59_15_vray
# models_core.json chain_purse
# models_core.json chair_annabelle
# models_core.json chair_billiani_doll
# models_core.json chair_eames_plastic_armchair
# models_core.json chair_thonet_marshall
# models_core.json chair_willisau_riale
# models_core.json champagne_cork
# models_core.json chista_slice_of_teak_table
# models_core.json chocolate_bar001
# models_core.json club_house_italia_nautilus_sofa
# models_core.json coffee_001
# models_core.json coffee_0023
# models_core.json coffee_005_13
# models_core.json coffee_cup
# models_core.json coffee_grinder
# models_core.json coffee_maker
# models_core.json coffee_table_glass_round
# models_core.json coffeecup004
# models_core.json coffeecup004_fix
# models_core.json coffeemug
# models_core.json cork_plastic
# models_core.json cork_plastic_black
# models_core.json cucharon_utensilios
# models_core.json cup
# models_core.json cylinder001
# models_core.json cylinder01
# models_core.json dark_red_club_chair
# models_core.json db_apps_tech_08_10_composite
# models_core.json de_castelli_placas_table
# models_core.json de_castelli_placas_table_low
# models_core.json desk_lamp
# models_core.json dewalt_compact_drill_vray
# models_core.json dining_room_table
# models_core.json dishwasher_4
# models_core.json dishwasher_4_composite
# models_core.json duffle_bag
# models_core.json duffle_bag_sm
# models_core.json duhovka
# models_core.json dumb-bell_2010
# models_core.json duncan_floor_lamp_crate_and_barrel
# models_core.json easter4
# models_core.json elephant_bowl
# models_core.json elf_painting
# models_core.json emeco_navy_chair
# models_core.json engineers_hammer_vray
# models_core.json enzo_industrial_loft_pine_metal_round_dining_table
# models_core.json f10_apple_iphone_4
# models_core.json filler_2010
# models_core.json fire_extinguisher
# models_core.json fire_extinguisher_(max2014)
# models_core.json flat_woven_rug
# models_core.json fork1
# models_core.json fork2
# models_core.json fork3
# models_core.json fork4
# models_core.json foscarini_cage_mic_lamp
# models_core.json framed_painting
# models_core.json fredericia_spine_stool_1
# models_core.json fridge_large
# models_core.json fridge_large_composite
# models_core.json fruit_basket
# models_core.json gas_stove
# models_core.json gas_stove_composite
# models_core.json generic_toothbrush_001
# models_core.json glass1
# models_core.json glass2
# models_core.json glass3
# models_core.json glass_coffee_table_long
# models_core.json glass_table
# models_core.json glass_table_round
# models_core.json golf
# models_core.json green_bag
# models_core.json green_side_chair
# models_core.json h-shape_wood_block
# models_core.json hair_comb_2010
# models_core.json half_circle_wood_block
# models_core.json heart
# models_core.json hexagonal_toy
# models_core.json hiker_backpack
# models_core.json holy_bible
# models_core.json hp_printer
# models_core.json int_kitchen_accessories_le_creuset_bowl_30cm
# models_core.json int_kitchen_accessories_le_creuset_frying_pan_28cm
# models_core.json iron_box
# models_core.json its_about_time_painting
# models_core.json jigsaw_puzzle_composite
# models_core.json jug01
# models_core.json jug02
# models_core.json jug03
# models_core.json jug04
# models_core.json jug05
# models_core.json juicer
# models_core.json kenmore_refr_74049_composite
# models_core.json kettle
# models_core.json kettle_2
# models_core.json kevin_reilly_pattern_table_lamp
# models_core.json key_brass
# models_core.json key_dull_metal
# models_core.json key_shiny
# models_core.json kids_luggage_1
# models_core.json kids_luggage_2
# models_core.json kitchen_aid_coffee_grinder
# models_core.json kitchen_faucet
# models_core.json kitchen_sieve
# models_core.json knife1
# models_core.json knife2
# models_core.json knife3
# models_core.json kosmos_black_soap_dispenser
# models_core.json l-shape_wood_block
# models_core.json lamp_02
# models_core.json lantern_2010
# models_core.json lapalma_stil_chair
# models_core.json large_mesh_basket
# models_core.json lawnmower
# models_core.json lg_table_marble_green
# models_core.json lg_table_white
# models_core.json lighter
# models_core.json ligne_roset_armchair
# models_core.json linbrazil_diz_armchair
# models_core.json linen_dining_chair
# models_core.json lint_roller01
# models_core.json lint_roller02
# models_core.json lint_roller03
# models_core.json lint_roller04
# models_core.json lint_roller05
# models_core.json live_edge_coffee_table
# models_core.json luggage_bag_1
# models_core.json macbook_air
# models_core.json marble_table
# models_core.json marble_table_white
# models_core.json mater_high_stool_al_69
# models_core.json measuring_pan
# models_core.json meridiani_belmondo_bench_sofa
# models_core.json meridiani_freeman_sofa
# models_core.json metal_briefcase
# models_core.json metal_lab_shelf
# models_core.json metal_lab_table
# models_core.json metal_sculpture
# models_core.json microwave
# models_core.json microwave_composite
# models_core.json minotti_helion_3_seater_sofa
# models_core.json moet_chandon_bottle_vray
# models_core.json molteni_turner_sofa
# models_core.json monster_beats_studio
# models_core.json mouse_02_vray
# models_core.json mouse_m505_1
# models_core.json mug
# models_core.json napoleon_iii_sofa
# models_core.json naughtone_pinch_stool_chair
# models_core.json notes_02
# models_core.json object05
# models_core.json omega_seamaster_set
# models_core.json on_the_rocks_sofa
# models_core.json orange
# models_core.json pan01
# models_core.json pan02
# models_core.json pan03
# models_core.json pan04
# models_core.json pan05
# models_core.json pan1
# models_core.json pan3
# models_core.json pcylinder222
# models_core.json pencil_all
# models_core.json pentagon_wood_block
# models_core.json pepper
# models_core.json pillow
# models_core.json pillow01
# models_core.json pillow02
# models_core.json pillow03
# models_core.json pillow04
# models_core.json pillow05
# models_core.json pillow06
# models_core.json pillow07
# models_core.json pillow08
# models_core.json pixamoon_free_test_faucet_001_publish
# models_core.json plate05
# models_core.json plate06
# models_core.json plate07
# models_core.json poliform_atollo_curved_sofa
# models_core.json poliform_park_low_arm_sofa
# models_core.json pot
# models_core.json pot_composite
# models_core.json printer_hp_laserjet1321
# models_core.json purple_woven_rug
# models_core.json purse
# models_core.json puzzle_box_composite
# models_core.json quatre_dining_table
# models_core.json radiator_pub_2015
# models_core.json rattan_basket
# models_core.json rectangle_wood_block
# models_core.json red_bag
# models_core.json red_lamp
# models_core.json red_side_chair
# models_core.json refridgerator_slim
# models_core.json remote_vr_2012
# models_core.json rh1
# models_core.json rh10
# models_core.json rh18
# models_core.json ripple
# models_core.json rope_table_lamp
# models_core.json round_bowl_large_metal_perf
# models_core.json round_bowl_large_padauk
# models_core.json round_bowl_large_thin
# models_core.json round_bowl_small_beech
# models_core.json round_bowl_small_walnut
# models_core.json round_bowl_talll_wenge
# models_core.json round_coaster_cherry
# models_core.json round_coaster_indent_rubber
# models_core.json round_coaster_indent_stone
# models_core.json round_coaster_indent_wood
# models_core.json round_coaster_stone
# models_core.json round_coaster_stone_dark
# models_core.json russell_hobbs_2013__vray
# models_core.json salt
# models_core.json salt_shaker
# models_core.json satiro_sculpture
# models_core.json sayonara_sofa
# models_core.json scissors
# models_core.json serving_bowl
# models_core.json servingfork
# models_core.json shallow_basket_white_mesh
# models_core.json shallow_basket_wicker
# models_core.json shark
# models_core.json shoebox_fused
# models_core.json side_table_wood
# models_core.json silver_frame_painting
# models_core.json sink_base_white_wood
# models_core.json sink_base_wood_beach_honey
# models_core.json sink_cabinet_unit_wood_beech_honey_chrome_composite
# models_core.json sink_cabinet_unit_wood_beech_honey_porcelain_composite
# models_core.json sink_cabinet_unit_wood_oak_white_chrome_composite
# models_core.json sink_cabinet_unit_wood_oak_white_porcelain_composite
# models_core.json skateboard_1
# models_core.json skillet_closed
# models_core.json skillet_open
# models_core.json skillet_open_no_lid
# models_core.json slotted_spatula_black02
# models_core.json sm_table_white
# models_core.json small_purse
# models_core.json small_table_green_marble
# models_core.json soap_dispenser_01
# models_core.json soup_ladle_black_02
# models_core.json spagetti-server
# models_core.json spatula
# models_core.json spatula2
# models_core.json spatula3
# models_core.json spoon1
# models_core.json spoon2
# models_core.json spunlight_designermesh_lamp
# models_core.json square_coaster_001_cork
# models_core.json square_coaster_001_marble
# models_core.json square_coaster_001_wood
# models_core.json square_coaster_rubber
# models_core.json square_coaster_stone
# models_core.json square_coaster_wood
# models_core.json square_wood_block
# models_core.json stack_of_cups_composite
# models_core.json star_wood_block
# models_core.json steam-punk_gear_25
# models_core.json steam-punk_gear_27
# models_core.json steam-punk_gear_29
# models_core.json stelton_emma_tea_vacuum_jug
# models_core.json t-shape_wood_block
# models_core.json table_square
# models_core.json table_stack
# models_core.json tablespoon
# models_core.json tan_lounger_chair
# models_core.json tan_purse
# models_core.json tan_side_chair
# models_core.json tapered_cork
# models_core.json tapered_cork_w_hole
# models_core.json tea_kettle_model
# models_core.json teakettle_01
# models_core.json teatray
# models_core.json toaster_002
# models_core.json toaster_b
# models_core.json tolix_bar_stool
# models_core.json toothbrush
# models_core.json toy_monkey_medium
# models_core.json trapezoidal_table
# models_core.json trashbin
# models_core.json tray_02
# models_core.json trophy01
# models_core.json trophy02
# models_core.json trunck
# models_core.json v3_tf_04_01
# models_core.json vase_01
# models_core.json vase_02
# models_core.json vase_03
# models_core.json vase_05
# models_core.json vase_06
# models_core.json vase_laura_deko_vase_set
# models_core.json vitra_meda_chair
# models_core.json vk0002_teaspoon
# models_core.json vk0007_steak_knife
# models_core.json vk0010_dinner_fork_subd0
# models_core.json vk0011_dessert_fork_subd0
# models_core.json vk0014_dinner_knife_subd2
# models_core.json vk0054_teaspoon
# models_core.json vk0055_tableknife
# models_core.json vk0056_tablefork
# models_core.json vk0058_tablespoon
# models_core.json vk0060_dessertspoon
# models_core.json vk0067_fishfork
# models_core.json vk0078_fruitspoon
# models_core.json vk0080_soupspoon
# models_core.json vm_v5_070
# models_core.json vm_v5_070_composite
# models_core.json vray_032
# models_core.json vray_041
# models_core.json vray_043
# models_core.json vray_044
# models_core.json vray_062
# models_core.json vray_062_composite
# models_core.json vray_077
# models_core.json vray_077_composite
# models_core.json vray_083
# models_core.json vray_083_composite
# models_core.json vray_084
# models_core.json vray_084_composite
# models_core.json vray_085
# models_core.json vray_085_composite
# models_core.json vraymax2013_oven_akzm6610ixl_by_whirlpool
# models_core.json whisk
# models_core.json white_club_chair
# models_core.json white_lamp
# models_core.json white_lounger_chair
# models_core.json white_shopping_bag
# models_core.json willisau_varion_w3_table
# models_core.json wood_board
# models_core.json wood_chair
# models_core.json wooden_pepper_mill
# models_core.json woven_box
# models_core.json yellow_side_chair
# models_core.json zenblocks
# models_core.json zippo
# models_full.json 004_rose_pink
# models_full.json 005_calendula
# models_full.json 006_max
# models_full.json 008_vray
# models_full.json 009_vray_fix
# models_full.json 012_vray
# models_full.json 013_dahlia_tall
# models_full.json 013_vray
# models_full.json 014_vray
# models_full.json 02
# models_full.json 020_vray
# models_full.json 021_vray
# models_full.json 022_vray_fix
# models_full.json 023_vray
# models_full.json 024_vray
# models_full.json 027
# models_full.json 028_lily
# models_full.json 034_vray
# models_full.json 035_vray
# models_full.json 03_106
# models_full.json 07_01_001
# models_full.json 102_pepsi_can_12_fl_oz_vray
# models_full.json 104_sprite_can_12_fl_oz_vray
# models_full.json 10965_box01
# models_full.json 10_euro_bill
# models_full.json 10_euros
# models_full.json 11_02_003
# models_full.json 11_02_046
# models_full.json 129601_sheep
# models_full.json 12_01_001
# models_full.json 12_01_002
# models_full.json 12_01_010
# models_full.json 12_01_013
# models_full.json 12_01_015
# models_full.json 12_01_023
# models_full.json 12_06_001
# models_full.json 133
# models_full.json 17th_c._monastery_dining_table_2010
# models_full.json 19403_cow
# models_full.json 1_fix
# models_full.json 2
# models_full.json 2012-2
# models_full.json 203
# models_full.json 24_in_wall_cabinet_white_wood
# models_full.json 24_in_wall_cabinet_wood_beach_honey
# models_full.json 27
# models_full.json 2_fix
# models_full.json 36_in_wall_cabinet_white_wood
# models_full.json 36_in_wall_cabinet_wood_beach_honey
# models_full.json 3dscan_man_002
# models_full.json 3dscan_man_003
# models_full.json 3dscan_man_004
# models_full.json 3dscan_man_011
# models_full.json 3dscan_man_012
# models_full.json 3dscan_woman_001
# models_full.json 3dscan_woman_002
# models_full.json 4_strela_elementi_blagoustroistva_v-ray_2011
# models_full.json 4ft_shelf_metal
# models_full.json 4ft_wood_shelving
# models_full.json 5ft_shelf_metal
# models_full.json 5ft_wood_shelving
# models_full.json 608_black
# models_full.json 625445_crocodile
# models_full.json 636591_sheep
# models_full.json 644254_dart
# models_full.json 648972_chair_poliform_harmony
# models_full.json 659968_air_baloon
# models_full.json 688899_stringer
# models_full.json 688926_elephant
# models_full.json 688947_spider
# models_full.json 699264_shoppingcart_2013
# models_full.json 6ft_shelf_metal
# models_full.json 6ft_wood_shelving
# models_full.json 703464_elephant
# models_full.json 735737_zebra
# models_full.json 736684_elephant
# models_full.json 737-500
# models_full.json 808409_toothbrush
# models_full.json 839104_rat
# models_full.json 868573_pliers_max2016
# models_full.json 868576_pliers_max2016
# models_full.json 868580_pliers_max2016
# models_full.json 868581_pliers_max2016
# models_full.json 885557_horse
# models_full.json 885577_spider
# models_full.json 886673_duck
# models_full.json 889143_rat
# models_full.json 889242_mesh
# models_full.json 915131_object001
# models_full.json 9v_battery
# models_full.json aaa_battery
# models_full.json acacia_table_lamp_jamie_young
# models_full.json acacia_table_lamp_jamie_young_composite
# models_full.json acb90
# models_full.json acer_chromebox_cxi_vray
# models_full.json achelata
# models_full.json acoustic_guitar
# models_full.json actros_max2009
# models_full.json adirondack_chair
# models_full.json afl_lamp
# models_full.json air_baloon_scanline
# models_full.json akm_3dsmax2014
# models_full.json alarm_clock
# models_full.json alarm_clock_01-01_2010
# models_full.json alfa_be1022_tv
# models_full.json alivar_tech_bench_sofa
# models_full.json alma_floor_lamp
# models_full.json am124_148_v7
# models_full.json am150_013
# models_full.json am151_043_00
# models_full.json am151_045_00
# models_full.json am159_076
# models_full.json am159_078
# models_full.json ammo_002
# models_full.json amphora_jar_vase
# models_full.json animal_dog_rtsit_1280
# models_full.json animal_dog_rtsit_1282
# models_full.json animal_dog_rtstand_1281
# models_full.json antique_coffee_grinder
# models_full.json antique_globe01
# models_full.json antique_globe02
# models_full.json antique_globe03
# models_full.json antique_globes
# models_full.json antique_pepper_grinder
# models_full.json anubias_st
# models_full.json apple
# models_full.json apple-notebook-g4
# models_full.json apple04(8_vray)
# models_full.json apple07(8_vray)
# models_full.json apple_2
# models_full.json apple_ipod_touch_grey_vray
# models_full.json apple_ipod_touch_pink_vray
# models_full.json apple_ipod_touch_yellow_vray
# models_full.json apple_magic_mouse_2_(2015)_vray
# models_full.json apple_remote
# models_full.json apple_watch_38mm_rose_gold_case_with_white_sport_band_vray
# models_full.json appliance-ge-profile-microwave
# models_full.json appliance-ge-profile-microwave3
# models_full.json appliance-ge-profile-microwave3_composite
# models_full.json appliance-ge-profile-microwave_composite
# models_full.json aquostv
# models_full.json arco_lamp
# models_full.json areti_bonhomme01
# models_full.json areti_bonhomme02
# models_full.json areti_bonhomme_vray
# models_full.json arflex_hollywood_sofa
# models_full.json arflex_strips_sofa
# models_full.json arm004-00-w
# models_full.json artefacto_maxim_bench_max
# models_full.json artis_bike
# models_full.json artis_run
# models_full.json artist_brush
# models_full.json arturoalvarez_v_floor_lamp
# models_full.json aruba_boat
# models_full.json aspen_oval_mirror_jeffan
# models_full.json assorted_metal_burlap_basket
# models_full.json asus_chromebox_vray
# models_full.json atm_machine02
# models_full.json atmosphere_nodo
# models_full.json audia7_2018_vray
# models_full.json avio_bonne_voyage_trunk
# models_full.json axe
# models_full.json axe_lowpoly
# models_full.json axe_max_2011
# models_full.json azor
# models_full.json b006_clyde-clock_vray
# models_full.json b01_023_vray
# models_full.json b01_alarm_clock
# models_full.json b01_bag
# models_full.json b01_baker_marco_vase_vray
# models_full.json b01_beach_chair
# models_full.json b01_cassette
# models_full.json b01_croissant
# models_full.json b01_digital_thermometer
# models_full.json b01_door
# models_full.json b01_group1
# models_full.json b01_lock
# models_full.json b01_padlock
# models_full.json b01_shark
# models_full.json b01_shovel
# models_full.json b01_spatula
# models_full.json b01_tennis_racket
# models_full.json b01_tent
# models_full.json b01_traffic_light
# models_full.json b01_trumpet
# models_full.json b01_turtle
# models_full.json b02_023_vray
# models_full.json b02_bag
# models_full.json b02_beach_chair
# models_full.json b02_cassette
# models_full.json b02_croissant
# models_full.json b02_digital_thermometer
# models_full.json b02_door
# models_full.json b02_group1
# models_full.json b02_lock
# models_full.json b02_padlock
# models_full.json b02_piano
# models_full.json b02_shovel
# models_full.json b02_tennis_racket
# models_full.json b02_tent
# models_full.json b02_traffic_light
# models_full.json b02_turtle
# models_full.json b03_003
# models_full.json b03_027_vray
# models_full.json b03_05
# models_full.json b03_065_vray
# models_full.json b03_12_01_003
# models_full.json b03_12_01_016
# models_full.json b03_12_06_027
# models_full.json b03_15
# models_full.json b03_1951_vintage_life_preserver_ring
# models_full.json b03_2011
# models_full.json b03_202435_3d-model
# models_full.json b03_210822_layer0_001
# models_full.json b03_325_bear
# models_full.json b03_38_special_-_max_2012_(vray)
# models_full.json b03_3wheels
# models_full.json b03_47893_lawnmover_new
# models_full.json b03_643271_lawnmover_new
# models_full.json b03_671300_bee
# models_full.json b03_696615_object001
# models_full.json b03_716828_mesh
# models_full.json b03_723329_croissant
# models_full.json b03_745118_bear
# models_full.json b03_817068_axe
# models_full.json b03_825236_crocodile
# models_full.json b03_835113_cylinder01
# models_full.json b03_839675_cow
# models_full.json b03_852100_giraffe
# models_full.json b03_876902_crocodile
# models_full.json b03_880955_money
# models_full.json b03_880969_money
# models_full.json b03_880976_money
# models_full.json b03_adirondack_chair
# models_full.json b03_adjustable_dumbbell
# models_full.json b03_air_baloon
# models_full.json b03_air_baloon_scanline
# models_full.json b03_alienware17_2012__vray
# models_full.json b03_aluminum_pan
# models_full.json b03_aluminum_pan_composite
# models_full.json b03_animal_dog_rtstand_1228
# models_full.json b03_axe_new
# models_full.json b03_backgammon
# models_full.json b03_backpack
# models_full.json b03_banan_001
# models_full.json b03_banana_01_high
# models_full.json b03_base
# models_full.json b03_baseball-bats
# models_full.json b03_baseball_02
# models_full.json b03_basket
# models_full.json b03_basset_hound
# models_full.json b03_bat_mesh
# models_full.json b03_bear
# models_full.json b03_beats_solo_hd_headphone_03_2010
# models_full.json b03_bfg_silvertoown
# models_full.json b03_bfgoodrich_steelrim_2011vr
# models_full.json b03_blue_edition_liquid_soap
# models_full.json b03_boat_fishing_02_null_11
# models_full.json b03_bosch_cbg675bs1b_2013__vray
# models_full.json b03_bosch_cbg675bs1b_2013__vray_composite
# models_full.json b03_boss-extru
# models_full.json b03_box
# models_full.json b03_box004
# models_full.json b03_box01
# models_full.json b03_brush_circle
# models_full.json b03_bucket
# models_full.json b03_burger
# models_full.json b03_bus-sum_wom_rtsit_716
# models_full.json b03_caiman
# models_full.json b03_cake
# models_full.json b03_calf
# models_full.json b03_calligraphybrush_circle
# models_full.json b03_can-opened
# models_full.json b03_canoe_01_(2013_default)
# models_full.json b03_cat3smooth
# models_full.json b03_cat_mesh
# models_full.json b03_catering_laddle
# models_full.json b03_ceiling_fan_-_hanter_bridgeport_black_with_wood
# models_full.json b03_cgaxis_models_19_16_01
# models_full.json b03_cgaxis_models_66_05_vray
# models_full.json b03_city_bus_nova
# models_full.json b03_closed_soda_can
# models_full.json b03_cocacola_can_cage
# models_full.json b03_cockroach_mesh
# models_full.json b03_coffee_cup
# models_full.json b03_cooking_pot_01
# models_full.json b03_cooking_pot_01_composite
# models_full.json b03_coping_saw_vray
# models_full.json b03_cow
# models_full.json b03_cpu_chasis
# models_full.json b03_crab_main_exp1
# models_full.json b03_crocodile
# models_full.json b03_crocodile_01
# models_full.json b03_cups_trophy_max_2011
# models_full.json b03_cuvier_beaked_whale
# models_full.json b03_cylinder004
# models_full.json b03_dagger
# models_full.json b03_dardo01
# models_full.json b03_dark_bon_chocolate
# models_full.json b03_dart_001
# models_full.json b03_db_apps_tech_08_01
# models_full.json b03_db_apps_tech_08_01_composite
# models_full.json b03_db_apps_tech_08_04
# models_full.json b03_db_apps_tech_08_04_composite
# models_full.json b03_db_apps_tech_08_07
# models_full.json b03_db_apps_tech_08_07_composite
# models_full.json b03_db_apps_tech_08_08
# models_full.json b03_db_apps_tech_08_08_composite
# models_full.json b03_default
# models_full.json b03_dh01_max
# models_full.json b03_dice
# models_full.json b03_djembe
# models_full.json b03_dl3d_vacuum
# models_full.json b03_dollarstack
# models_full.json b03_donut_max2012
# models_full.json b03_door_013
# models_full.json b03_door_handle02
# models_full.json b03_door_knob_max2014
# models_full.json b03_dove_polysurface1
# models_full.json b03_dumbbell_vray
# models_full.json b03_ec135_police_vray
# models_full.json b03_ec135_vray
# models_full.json b03_elephant
# models_full.json b03_elpheyel
# models_full.json b03_eurocopter-vray
# models_full.json b03_fan
# models_full.json b03_fire_hydrant
# models_full.json b03_fire_hydrant_13(1)
# models_full.json b03_fire_hydrant_los_angeles(1)
# models_full.json b03_firestone_wirerim_2011vr
# models_full.json b03_fleetwood_bounder_1986
# models_full.json b03_folding-screen-panel-room-divider
# models_full.json b03_forklift_jungheinrich_02
# models_full.json b03_gaz_volga_m21_3_series_3ds_max_2014_vray_3
# models_full.json b03_giraffe
# models_full.json b03_giraffe_mesh
# models_full.json b03_globe
# models_full.json b03_globe_sml
# models_full.json b03_golf_cart
# models_full.json b03_golf_cart_vray
# models_full.json b03_golfcart01
# models_full.json b03_grandpiano2014
# models_full.json b03_green_apple
# models_full.json b03_group1
# models_full.json b03_gs_mug
# models_full.json b03_hack_saw_vray
# models_full.json b03_hair_comb_2010
# models_full.json b03_hand_saw_max
# models_full.json b03_hand_saw_vray
# models_full.json b03_headphone__max2014
# models_full.json b03_holo3d-mesh-snake
# models_full.json b03_holo3d-python
# models_full.json b03_horse
# models_full.json b03_hotairbal_1
# models_full.json b03_hourglasses
# models_full.json b03_hummingbird
# models_full.json b03_iron_candle_vray
# models_full.json b03_jonathan_adler_talitha_white_heart_throw_pillow
# models_full.json b03_joseph_jeup_-_aiden_bench
# models_full.json b03_ka90ivi20r_2013__vray
# models_full.json b03_ka90ivi20r_2013__vray_composite
# models_full.json b03_kayak01
# models_full.json b03_killerwhale
# models_full.json b03_knot_stool
# models_full.json b03_krapfens_max2012
# models_full.json b03_krizak-scanline_max2011
# models_full.json b03_kundura
# models_full.json b03_labyrinth_game
# models_full.json b03_lamp
# models_full.json b03_lamp_composite
# models_full.json b03_large_chinese_drum
# models_full.json b03_lawnmover01
# models_full.json b03_lawntractor01
# models_full.json b03_life_preserver_ring
# models_full.json b03_life_preserver_ring_1
# models_full.json b03_life_ring_ohio_wholesale_inc
# models_full.json b03_loafbread
# models_full.json b03_low_poly_ballon
# models_full.json b03_low_poly_realistic_crocodile_max
# models_full.json b03_low_poly_realistic_tortoise_max
# models_full.json b03_m510_2012__vray
# models_full.json b03_madefun3d_brownbear
# models_full.json b03_mando
# models_full.json b03_mando_samsung_max
# models_full.json b03_max
# models_full.json b03_mesh
# models_full.json b03_mesh_asian_elephant
# models_full.json b03_microscope
# models_full.json b03_mis_en_demeure_-_ecouen_bench
# models_full.json b03_mis_en_demeure_-_maillot_ebene_mirror
# models_full.json b03_morphy_2013__vray
# models_full.json b03_motor_boat
# models_full.json b03_motor_home_2
# models_full.json b03_motorboat_speedboat
# models_full.json b03_mountainboardfull
# models_full.json b03_mouse_aw558_2013__vray
# models_full.json b03_nautical_life_ring_decor_ohio_wholesale_inc
# models_full.json b03_nautical_marine_room_life_preserver
# models_full.json b03_navara-boat
# models_full.json b03_niamh_barry_-_falling_light_sculpture
# models_full.json b03_nognicy_003
# models_full.json b03_nokia_e7-00_vray
# models_full.json b03_nysubway_3dsmax_2015
# models_full.json b03_object001
# models_full.json b03_object05
# models_full.json b03_objline01
# models_full.json b03_old_radio_3ds_max_2014
# models_full.json b03_old_scissors
# models_full.json b03_orange
# models_full.json b03_orange_(3dsmax2013_vray2)
# models_full.json b03_oscar_statue
# models_full.json b03_padlock
# models_full.json b03_pain_au_chocolat
# models_full.json b03_pans
# models_full.json b03_parchessi_vray
# models_full.json b03_pcylinder2
# models_full.json b03_pen
# models_full.json b03_pen_01_001
# models_full.json b03_pen_4colours
# models_full.json b03_piccolo_trumpet_vray
# models_full.json b03_pink_donuts_mesh
# models_full.json b03_plane001
# models_full.json b03_plane002
# models_full.json b03_polycarbonate_trolley_frame_03
# models_full.json b03_pot
# models_full.json b03_pot_and_jug
# models_full.json b03_pot_plant_20_2013__vray
# models_full.json b03_punching_bag
# models_full.json b03_radiator_alum_12
# models_full.json b03_radiator_old
# models_full.json b03_ram_mesh
# models_full.json b03_rat
# models_full.json b03_rayban_lenon
# models_full.json b03_realistic_muscular_horse_max
# models_full.json b03_realistic_pigeon_max
# models_full.json b03_rectangle01
# models_full.json b03_restoration_hardware_pedestal_salvaged_round_tables
# models_full.json b03_reversi_vray
# models_full.json b03_revolver
# models_full.json b03_roller_skate
# models_full.json b03_s_mailbox_01
# models_full.json b03_salt_and_pepper
# models_full.json b03_samsung_da_e750_dock_speaker_2013__vray
# models_full.json b03_scarab_beetle
# models_full.json b03_scissors
# models_full.json b03_scrabble_vray
# models_full.json b03_screw_driver
# models_full.json b03_set
# models_full.json b03_shape001
# models_full.json b03_sheep
# models_full.json b03_sheep_2_low_poly
# models_full.json b03_shopping_cart
# models_full.json b03_shopping_cart_walmart
# models_full.json b03_shoppingcart_2013
# models_full.json b03_shovel
# models_full.json b03_shovel_02
# models_full.json b03_simpsons_london_-_round_hudson_mirror
# models_full.json b03_slippers
# models_full.json b03_slippers2_new
# models_full.json b03_slippers_new
# models_full.json b03_sneakers_10
# models_full.json b03_soduku_board_vray
# models_full.json b03_sparrow
# models_full.json b03_sphere_chocolate
# models_full.json b03_spider
# models_full.json b03_spoon_001
# models_full.json b03_still_forklift
# models_full.json b03_stone_rock_vray_gamma2_2_2013
# models_full.json b03_stringer
# models_full.json b03_sun_flower
# models_full.json b03_surfboard
# models_full.json b03_surfboard_02
# models_full.json b03_swing_13
# models_full.json b03_swing_14
# models_full.json b03_t_shirt
# models_full.json b03_tall_pan_and_measuring_pan
# models_full.json b03_the_sofa_and_chair_company_-_stanley_bed_2014
# models_full.json b03_toothbrush
# models_full.json b03_topkicktruck
# models_full.json b03_towel_set_17
# models_full.json b03_trailer
# models_full.json b03_traveller_maroon_hat
# models_full.json b03_treadmill_t7xe
# models_full.json b03_trumpet
# models_full.json b03_trumpet_vray
# models_full.json b03_ts8150_2013__vray
# models_full.json b03_turtle
# models_full.json b03_tv_controller_2013__vray
# models_full.json b03_v1_tm_beds_19
# models_full.json b03_vedro
# models_full.json b03_vintage_life_preserver
# models_full.json b03_vintage_phone
# models_full.json b03_vise
# models_full.json b03_vm_hg2_025_umbrella
# models_full.json b03_vm_hg2_047_vacuum
# models_full.json b03_vm_hg2_048_vacuum
# models_full.json b03_vys_vozik2_scanline_2011
# models_full.json b03_wheelchair
# models_full.json b03_woodcraft-hammer
# models_full.json b03_worldglobe
# models_full.json b03_yuanforce_zebra
# models_full.json b03_zebra
# models_full.json b03_zebra_body
# models_full.json b03_zebra_max
# models_full.json b03_zebra_mesh
# models_full.json b03_zippo_lighter_cigar
# models_full.json b03_zippo_lighters_max2013
# models_full.json b04_015_sculpture_m
# models_full.json b04_03_077
# models_full.json b04_1106_backpack
# models_full.json b04_11_02_041
# models_full.json b04_1_new
# models_full.json b04_2
# models_full.json b04_3d-model
# models_full.json b04_3d_jar_180_gr_01
# models_full.json b04_661696_dog_house
# models_full.json b04__pdisc8
# models_full.json b04_a1
# models_full.json b04_a_mesh
# models_full.json b04_airstream_classic_max2014
# models_full.json b04_airstream_sport_max2014
# models_full.json b04_apple02_(8_vray)
# models_full.json b04_arm247-11_new
# models_full.json b04_armani_handbag
# models_full.json b04_at-0002
# models_full.json b04_axe
# models_full.json b04_b200003_01
# models_full.json b04_backpack
# models_full.json b04_banana
# models_full.json b04_baseball_bat
# models_full.json b04_baseball_collection_2011_
# models_full.json b04_basket
# models_full.json b04_bat_01
# models_full.json b04_baterijska_busilica
# models_full.json b04_bee
# models_full.json b04_bee_2012
# models_full.json b04_beetle_woodcutter_001
# models_full.json b04_bike
# models_full.json b04_black_grape
# models_full.json b04_blackspider
# models_full.json b04_blanco_metra_45_s_max
# models_full.json b04_boat_2
# models_full.json b04_boat_new
# models_full.json b04_bottle-2014-2018
# models_full.json b04_bottle-with-label
# models_full.json b04_bottle_20ml
# models_full.json b04_bottle_2_max
# models_full.json b04_bottle_max
# models_full.json b04_bowl_smooth
# models_full.json b04_brushflat
# models_full.json b04_brushround
# models_full.json b04_brushwide
# models_full.json b04_bucket
# models_full.json b04_bucketr
# models_full.json b04_ca
# models_full.json b04_cake_022(vray_2013)
# models_full.json b04_calculator
# models_full.json b04_calculator-object_only_scene
# models_full.json b04_can
# models_full.json b04_candle_holder_metal
# models_full.json b04_cantate_crystal_wine_glass
# models_full.json b04_car
# models_full.json b04_car32
# models_full.json b04_cassete
# models_full.json b04_cassette
# models_full.json b04_cat
# models_full.json b04_catia_stl
# models_full.json b04_cav_a
# models_full.json b04_cepillo
# models_full.json b04_cgaxis_models_31_12_vray
# models_full.json b04_cgaxis_models_32_22_vray
# models_full.json b04_cgaxis_models_50_06_vray
# models_full.json b04_cgaxis_models_57_06
# models_full.json b04_cgaxis_models_vray_29_13
# models_full.json b04_chair
# models_full.json b04_chair_02
# models_full.json b04_chalkboard_wine_glass
# models_full.json b04_champions_trophy
# models_full.json b04_child_bucket_and_spade_2014
# models_full.json b04_chinese_tea-tray-obj
# models_full.json b04_chocolate
# models_full.json b04_chocolate_donuts_mesh
# models_full.json b04_city_bus_with_interior_4_red_white
# models_full.json b04_clownfish
# models_full.json b04_coal_render_scene
# models_full.json b04_coffee_grinder_sunbeam_em0700
# models_full.json b04_coke_glass_vray
# models_full.json b04_comb
# models_full.json b04_comb_round_(max_2015)
# models_full.json b04_comb_round_max_2015
# models_full.json b04_combination_lock_2015
# models_full.json b04_converted
# models_full.json b04_cow
# models_full.json b04_cow_2017
# models_full.json b04_crab
# models_full.json b04_crab_2017
# models_full.json b04_cricket
# models_full.json b04_croissant
# models_full.json b04_croissant_max2013
# models_full.json b04_cup_nijniy_novgorod_gamma1.0_2013__vray
# models_full.json b04_cylinder01
# models_full.json b04_d_02
# models_full.json b04_dat
# models_full.json b04_db_apps_tech_08_03
# models_full.json b04_db_apps_tech_08_03_composite
# models_full.json b04_default
# models_full.json b04_dice_blue_glass_max_new
# models_full.json b04_dices_new
# models_full.json b04_diesel_shoes__original
# models_full.json b04_dog
# models_full.json b04_dog_house
# models_full.json b04_door_ln_61
# models_full.json b04_drill
# models_full.json b04_duck
# models_full.json b04_dump
# models_full.json b04_elephant
# models_full.json b04_elephant_2017
# models_full.json b04_extending_ladder
# models_full.json b04_faucet1
# models_full.json b04_fencerglove_rc01_zb04
# models_full.json b04_fifa_cup_new
# models_full.json b04_figure_2_node
# models_full.json b04_figure_3_node
# models_full.json b04_fireextinguisher
# models_full.json b04_fish_collection_04
# models_full.json b04_forklift
# models_full.json b04_forklifts
# models_full.json b04_fruit_basket_11
# models_full.json b04_fruit_basket_14
# models_full.json b04_geosphere001
# models_full.json b04_giant_rat
# models_full.json b04_gift_boxes_scene_max2015
# models_full.json b04_giraffe
# models_full.json b04_giraffegozdisplaced
# models_full.json b04_giraffelp
# models_full.json b04_girl_new
# models_full.json b04_glass
# models_full.json b04_glass_03_vray
# models_full.json b04_glass_04_vray
# models_full.json b04_glass_06_vray
# models_full.json b04_glass_07_vray
# models_full.json b04_glasses_6
# models_full.json b04_golden_apple
# models_full.json b04_golf_ball
# models_full.json b04_golf_ball_scene
# models_full.json b04_golf_car2012
# models_full.json b04_goose
# models_full.json b04_green_grapes
# models_full.json b04_green_grapes___fruit_basket_11
# models_full.json b04_grizzlybear
# models_full.json b04_group_001
# models_full.json b04_hair_dryer
# models_full.json b04_hand_and_dish_soap
# models_full.json b04_harley_davidson_3dsmax2014
# models_full.json b04_hat_cowboy
# models_full.json b04_headphones_31_12
# models_full.json b04_heineken_beer_vray
# models_full.json b04_helicopter
# models_full.json b04_helicopter_new
# models_full.json b04_hg01_mtr_v09
# models_full.json b04_hg03_max2009
# models_full.json b04_honey_jar
# models_full.json b04_honey_jar_max_2014
# models_full.json b04_horse_body_mesh
# models_full.json b04_hourglasses-set
# models_full.json b04_humming
# models_full.json b04_humpback_whale_exp1_0
# models_full.json b04_inlines
# models_full.json b04_iph8_sil_group_vray_max
# models_full.json b04_iphseroseg_group_vray_max
# models_full.json b04_iron_wire_round_scoop_baskets_with_seagrass
# models_full.json b04_jar_212ml
# models_full.json b04_jar_250ml
# models_full.json b04_jar_max_2014
# models_full.json b04_john_varvatos
# models_full.json b04_kenmore_refr_70419
# models_full.json b04_kevin_reilly_pattern_floor_lamp
# models_full.json b04_kiosk_1_2018
# models_full.json b04_kitchen_accessorie_09-02_2012
# models_full.json b04_ladle-dipper-scoop
# models_full.json b04_lawnm_new
# models_full.json b04_lawnmover02
# models_full.json b04_layer0_001
# models_full.json b04_leather_gloves
# models_full.json b04_lighter
# models_full.json b04_liquid_soap_dispenser_max2013
# models_full.json b04_longboard_skateboard_max2013
# models_full.json b04_low
# models_full.json b04_lowpoly
# models_full.json b04_lp
# models_full.json b04_m
# models_full.json b04_magicianhat
# models_full.json b04_mamba
# models_full.json b04_manitobe_bread_lowpoly
# models_full.json b04_medicine_bike_01
# models_full.json b04_mesh
# models_full.json b04_mesh_giraffe
# models_full.json b04_mexicanhat
# models_full.json b04_microscope_model
# models_full.json b04_microsoft_surface_pro
# models_full.json b04_milk_cow_low_poly_volume4
# models_full.json b04_money
# models_full.json b04_mouse_max_2016
# models_full.json b04_must_2012_max
# models_full.json b04_new
# models_full.json b04_nozhnitsy
# models_full.json b04_object001
# models_full.json b04_offshore_01
# models_full.json b04_old_pc
# models_full.json b04_orange_00
# models_full.json b04_p22732_cc_cp_2013
# models_full.json b04_p25050_slc_ad_2013
# models_full.json b04_paint_brush
# models_full.json b04_phone
# models_full.json b04_pigeon
# models_full.json b04_plane005
# models_full.json b04_plane03
# models_full.json b04_plastic_bucket
# models_full.json b04_pliers
# models_full.json b04_pliers_max
# models_full.json b04_policehat
# models_full.json b04_polysurface2
# models_full.json b04_qled_tv_remote
# models_full.json b04_radiator_max2013
# models_full.json b04_ramlosa_bottle_2015_vray
# models_full.json b04_rat
# models_full.json b04_rayban_standard_1
# models_full.json b04_red_grapes
# models_full.json b04_reform_ladder
# models_full.json b04_retro_radio
# models_full.json b04_roller_new
# models_full.json b04_roller_skates
# models_full.json b04_room_divider_3_vray2.00
# models_full.json b04_salt_and_pepper_wooden_shaker
# models_full.json b04_samsung_remotenew
# models_full.json b04_scania_render_scene
# models_full.json b04_scissors_2013
# models_full.json b04_screwdriver_render
# models_full.json b04_screwdriver_v2_texture_
# models_full.json b04_screwdriver_vray
# models_full.json b04_sheep
# models_full.json b04_ship_new
# models_full.json b04_shoppping_cart
# models_full.json b04_snake
# models_full.json b04_speedboat_vray
# models_full.json b04_spider
# models_full.json b04_stages_bunk_bedroom_set_bed
# models_full.json b04_stepladder
# models_full.json b04_stitch_result_stitch_all
# ...
# models_full.json pixamoon_free_test_faucet_001_publish
# models_full.json pizza
# models_full.json plate05
# models_full.json plate06
# models_full.json plate07
# models_full.json police_hat_vray
# models_full.json poliform_atollo_curved_sofa
# models_full.json poliform_park_low_arm_sofa
# models_full.json polysurface1707
# models_full.json polysurface63
# models_full.json polysurface7
# models_full.json pot
# models_full.json pot_composite
# models_full.json pot_plant_23_2013__vray
# models_full.json potted_plant
# models_full.json potted_plant_trellis
# models_full.json potted_plant_wide
# models_full.json printer_2014_max
# models_full.json printer_hp_laserjet1321
# models_full.json promemoria_-_montagu_bench
# models_full.json pruning_saw_vray
# models_full.json pull
# models_full.json punchingbag
# models_full.json punchingbag_large
# models_full.json punchingbag_medium
# models_full.json punchingbag_small
# models_full.json purple_woven_rug
# models_full.json purse
# models_full.json puzzle_box_composite
# models_full.json quatre_dining_table
# models_full.json racket
# models_full.json radiator
# models_full.json radiator_001
# models_full.json radiator_fix
# models_full.json radiator_pub_2015
# models_full.json ralph_lauren_home_-_one_fifth_screen_
# models_full.json ralph_lauren_sonora_canyon_sling_chair_max
# models_full.json ramp_with_platform_30
# models_full.json ramp_with_platform_60
# models_full.json ramp_with_platform_weld
# models_full.json rat_white
# models_full.json rattan_basket
# models_full.json rattlesnake_pose_2
# models_full.json recline_forma
# models_full.json recline_personal
# models_full.json rectangle_wood_block
# models_full.json red_apple
# models_full.json red_bag
# models_full.json red_cheesecake
# models_full.json red_grapes_fruit_basket_12
# models_full.json red_lamp
# models_full.json red_lounger_chair
# models_full.json red_side_chair
# models_full.json refridgerator_slim
# models_full.json refrigerator_small
# models_full.json remote_vr_2012
# models_full.json render_scene
# models_full.json restoration_hardware_chesterfield_full-over-full_bunk_bed
# models_full.json restoration_hardware_punching_bag
# models_full.json restoration_hardware_salvaged_tables
# models_full.json revival_rd60_radio
# models_full.json revolver
# models_full.json rh1
# models_full.json rh10
# models_full.json rh18
# models_full.json rh_leather_platform_bed_2011
# models_full.json ripple
# models_full.json riva63virtus_scanline
# models_full.json rockdove_polysurface77
# models_full.json rocket_diagram_large
# models_full.json rocket_diagram_small
# models_full.json roland_rg-1f
# models_full.json room_divider_2_vray2.00
# models_full.json rope_bucket
# models_full.json rope_table_lamp
# models_full.json rope_table_lamp_1
# models_full.json rope_table_lamp_1_composite
# models_full.json rope_table_lamp_2
# models_full.json rope_table_lamp_2_composite
# models_full.json round_bowl_large_metal_perf
# models_full.json round_bowl_large_padauk
# models_full.json round_bowl_large_thin
# models_full.json round_bowl_small_beech
# models_full.json round_bowl_small_walnut
# models_full.json round_bowl_talll_wenge
# models_full.json round_coaster_cherry
# models_full.json round_coaster_indent_rubber
# models_full.json round_coaster_indent_stone
# models_full.json round_coaster_indent_wood
# models_full.json round_coaster_stone
# models_full.json round_coaster_stone_dark
# models_full.json rpg_dices_set_hr
# models_full.json rubber_mallet_vray
# models_full.json ruble
# models_full.json rucksack
# models_full.json run_personal
# models_full.json russell_hobbs_2013__vray
# models_full.json s2v
# models_full.json s3x-h
# models_full.json s_tray_01
# models_full.json safe_3
# models_full.json safetyvault
# models_full.json safetyvault-2
# models_full.json salt
# models_full.json salt_mill_max_2013
# models_full.json salt_shaker
# models_full.json samsung_40_uhd_smart_tv_2011
# models_full.json samsung_refr_rf28k9380sg
# models_full.json samsung_refr_rs25j500dsr
# models_full.json samsungtv
# models_full.json sandals-3
# models_full.json satiro_sculpture
# models_full.json saw
# models_full.json sayonara_sofa
# models_full.json scania_concrete_mixer
# models_full.json scene_2010
# models_full.json schweppes_can_001
# models_full.json scissors
# models_full.json scissors_2014
# models_full.json screen_cloud
# models_full.json screwdriver
# models_full.json screwdriver_2010
# models_full.json screwdriver_2015
# models_full.json screwdriver_fix
# models_full.json sea_turtle_fix
# models_full.json seattle_double_bar_towel_set
# models_full.json selva_chest_of_dawers_5694_77x50xh75
# models_full.json serving_bowl
# models_full.json servingfork
# models_full.json set_of_towels_roll
# models_full.json shallow_basket_white_mesh
# models_full.json shallow_basket_wicker
# models_full.json shar_pei
# models_full.json shark
# models_full.json shark001
# models_full.json shirt
# models_full.json shirt_04
# models_full.json shirt_scanline
# models_full.json shirt_vray
# models_full.json shoebox_fused
# models_full.json shoes
# models_full.json shovel
# models_full.json shovelsellvr
# models_full.json showroomfinland_tuisku_50
# models_full.json side_table_wood
# models_full.json silver_frame_painting
# models_full.json simple_double_doors
# models_full.json sink_base_white_wood
# models_full.json sink_base_wood_beach_honey
# models_full.json sink_cabinet_unit_wood_beech_honey_chrome_composite
# models_full.json sink_cabinet_unit_wood_beech_honey_porcelain_composite
# models_full.json sink_cabinet_unit_wood_oak_white_chrome_composite
# models_full.json sink_cabinet_unit_wood_oak_white_porcelain_composite
# models_full.json skateboard_1
# models_full.json skateboard_2
# models_full.json skateboard_3
# models_full.json skateboard_4
# models_full.json skateboard_5
# models_full.json skateboard_long
# models_full.json skillet_closed
# models_full.json skillet_open
# models_full.json skillet_open_no_lid
# models_full.json skovor2
# models_full.json slipper_2010
# models_full.json slippers_large
# models_full.json slippers_medium
# models_full.json slippers_small
# models_full.json slit_lamp_ls_4
# models_full.json slotted_spatula_black02
# models_full.json sm_table_white
# models_full.json sm_tv
# models_full.json small_glass_bowl_water
# models_full.json small_mesh_basket
# models_full.json small_purse
# models_full.json small_scissors_hr
# models_full.json small_table_green_marble
# models_full.json snake
# models_full.json sneakers
# models_full.json snek_new
# models_full.json soap_dispenser_01
# models_full.json solocup
# models_full.json sony_w290_vray
# models_full.json soup_ladle_black_02
# models_full.json spa_bed_
# models_full.json spade
# models_full.json spade_vray
# models_full.json spagetti-server
# models_full.json spagheti-server
# models_full.json spatula
# models_full.json spatula2
# models_full.json spatula3
# models_full.json spazio_forma
# models_full.json speakers_09_vray
# models_full.json spinybacked
# models_full.json spitfire_2012
# models_full.json spo008__deck001
# models_full.json spoon1
# models_full.json spoon2
# models_full.json spunlight_designermesh_lamp
# models_full.json square_coaster_001_cork
# models_full.json square_coaster_001_marble
# models_full.json square_coaster_001_wood
# models_full.json square_coaster_rubber
# models_full.json square_coaster_stone
# models_full.json square_coaster_wood
# models_full.json square_wood_block
# models_full.json stack_10_euros
# models_full.json stack_of_cups_composite
# models_full.json stack_of_dollars
# models_full.json star_trac_spinner
# models_full.json star_trac_treadmill
# models_full.json star_wood_block
# models_full.json steam-punk_gear_25
# models_full.json steam-punk_gear_27
# models_full.json steam-punk_gear_28
# models_full.json steam-punk_gear_29
# models_full.json steam-punk_gear_30
# models_full.json steaming_pizza
# models_full.json stelton_emma_tea_vacuum_jug
# models_full.json stempunk_gears_01-vray
# models_full.json step_ladder
# models_full.json stf
# models_full.json stridabike_vray
# models_full.json stringer
# models_full.json stua_onda_stool_max2012
# models_full.json student_classical_guitar
# models_full.json studio_drill
# models_full.json stylized_tv
# models_full.json suicide_squad_bat_vray
# models_full.json suitcase
# models_full.json suitcase_fix
# models_full.json suitcase_with_money
# models_full.json sunglases_2016
# models_full.json surfboard_3
# models_full.json sweater
# models_full.json swing-001
# models_full.json swing_11
# models_full.json sword
# models_full.json t-shape_wood_block
# models_full.json t_shirt
# models_full.json tabla_2012
# models_full.json table_square
# models_full.json table_stack
# models_full.json table_vise_clamp
# models_full.json tablespoon
# models_full.json tall_pan
# models_full.json tan_lounger_chair
# models_full.json tan_purse
# models_full.json tan_side_chair
# models_full.json tapered_cork
# models_full.json tapered_cork_w_hole
# models_full.json tarap167
# models_full.json te_2a
# models_full.json tea_kettle_model
# models_full.json teakettle_01
# models_full.json teatray
# models_full.json teddy
# models_full.json teddy_bear_plush_toy
# models_full.json teepee
# models_full.json tennis-racket
# models_full.json tennis-racket-2
# models_full.json tennis_racket
# models_full.json tennis_rackets
# models_full.json tent
# models_full.json thermometer_3ds_max_2015
# models_full.json thin_laptop_stock_01
# models_full.json timberland_boot
# models_full.json tire_garfield
# models_full.json tireamericanclassic
# models_full.json toaster
# models_full.json toaster_002
# models_full.json toaster_b
# models_full.json tobias_grau_george_floor_lamp__1
# models_full.json toilet_3dsmax
# models_full.json tolix_bar_stool
# models_full.json toothbrush
# models_full.json toothbrush1_vray
# models_full.json toothbrush_2010
# models_full.json toothbrush_fix1
# models_full.json toothbrush_fix2
# models_full.json toothbrush_fix3
# models_full.json toothbrush_fix4
# models_full.json toothbrush_fix5
# models_full.json toothbrush_fix6
# models_full.json topiary_plant_l
# models_full.json topiary_plant_xl
# models_full.json topiary_plant_xxl
# models_full.json tort_for_sale_hp
# models_full.json towel-radiator-2
# models_full.json towel_roll
# models_full.json towel_set_03
# models_full.json towel_set_10
# models_full.json towel_set_15
# models_full.json towel_set_34
# models_full.json toy_dog
# models_full.json toy_monkey_large
# models_full.json toy_monkey_medium
# models_full.json toy_monkey_small
# models_full.json toy_sand_timer_hourglass_1
# models_full.json toy_train
# models_full.json tracket01_vray_max
# models_full.json traffic_light
# models_full.json traffic_light_srg
# models_full.json traffic_lights
# models_full.json traffic_lights_fix
# models_full.json traffic_lights_scene_max2015
# models_full.json traffic_lights_v1
# models_full.json trapezoidal_table
# models_full.json trash_can_max2017_vray_new
# models_full.json trashbin
# models_full.json tray_01_vray
# models_full.json tray_02
# models_full.json tray_05
# models_full.json trompet
# models_full.json trophy
# models_full.json trophy01
# models_full.json trophy02
# models_full.json trophy03
# models_full.json trophy04
# models_full.json trout
# models_full.json trumpet
# models_full.json trumpet001
# models_full.json trumpet_fix
# models_full.json trunck
# models_full.json trunk_6810-0009
# models_full.json ts8150_2013__vray
# models_full.json tt
# models_full.json turtle
# models_full.json tv_box
# models_full.json umbrella
# models_full.json umbrella_fix
# models_full.json universal_pliers_max
# models_full.json v3_tf_04_01
# models_full.json vacuum_box
# models_full.json vacuum_cleaner
# models_full.json vase_01
# models_full.json vase_02
# models_full.json vase_03
# models_full.json vase_05
# models_full.json vase_06
# models_full.json vase_laura_deko_vase_set
# models_full.json vault
# models_full.json vegetables
# models_full.json ventilatore
# models_full.json villaverde_-_murano_luna_chandelier
# models_full.json vintage_coffee_grinder
# models_full.json vintage_hand_painted_nautical_life_boat_preserver
# models_full.json vintage_step_ladder
# models_full.json vintage_usit_stepladder_chair_3_step_version
# models_full.json violin_4sell
# models_full.json vise
# models_full.json vise_blue_2014
# models_full.json vise_max
# models_full.json vitra_meda_chair
# models_full.json vk0002_teaspoon
# models_full.json vk0007_steak_knife
# models_full.json vk0009_butter_knife_subd0
# models_full.json vk0010_dinner_fork_subd0
# models_full.json vk0011_dessert_fork_subd0
# models_full.json vk0014_dinner_knife_subd2
# models_full.json vk0016_tea_fork_subd0
# models_full.json vk0054_teaspoon
# models_full.json vk0055_tableknife
# models_full.json vk0056_tablefork
# models_full.json vk0058_tablespoon
# models_full.json vk0060_dessertspoon
# models_full.json vk0067_fishfork
# models_full.json vk0072_steakknife
# models_full.json vk0073_teafork
# models_full.json vk0075_sodaspoon
# models_full.json vk0076_fruitfork
# models_full.json vk0078_fruitspoon
# models_full.json vk0080_soupspoon
# models_full.json vk0081_servingfork
# models_full.json vk0085_servingspoon
# models_full.json vk0086_piercedservingspoon
# models_full.json vk0091_carvingknife
# models_full.json vm_v2_015
# models_full.json vm_v2_024
# models_full.json vm_v2_027
# models_full.json vm_v3_050_cashpoint
# models_full.json vm_v5_024
# models_full.json vm_v5_046
# models_full.json vm_v5_070
# models_full.json vm_v5_070_composite
# models_full.json vm_v5_072
# models_full.json vray_004
# models_full.json vray_006
# models_full.json vray_012
# models_full.json vray_032
# models_full.json vray_041
# models_full.json vray_042
# models_full.json vray_043
# models_full.json vray_044
# models_full.json vray_060
# models_full.json vray_061
# models_full.json vray_062
# models_full.json vray_062_composite
# models_full.json vray_077
# models_full.json vray_077_composite
# models_full.json vray_083
# models_full.json vray_083_composite
# models_full.json vray_084
# models_full.json vray_084_composite
# models_full.json vray_085
# models_full.json vray_085_composite
# models_full.json vray_31_03
# models_full.json vraymax2013_oven_akzm6610ixl_by_whirlpool
# models_full.json vysokozdvizny_vozik
# models_full.json washingmachine_box
# models_full.json whale_fix
# models_full.json whale_killer
# models_full.json wheel_chair
# models_full.json whirlpool_akzm7630ix
# models_full.json whisk
# models_full.json white_club_chair
# models_full.json white_lamp
# models_full.json white_lounger_chair
# models_full.json white_shopping_bag
# models_full.json wicker_basket_03(vray)
# models_full.json wicker_hamper
# models_full.json wicker_trunk10_toasted_oat(vray)
# models_full.json willisau_varion_w3_table
# models_full.json wine_bottle
# models_full.json wine_box_vray
# models_full.json wineglass1
# models_full.json witcher_sword_2011
# models_full.json woman_manequin_4_2011
# models_full.json woman_manequin_5_2011
# models_full.json wood_board
# models_full.json wood_chair
# models_full.json woodbowl_a02
# models_full.json wooden_box
# models_full.json wooden_bucket_hr
# models_full.json wooden_chest_2009
# models_full.json wooden_pepper_mill
# models_full.json woven_box
# models_full.json x2015
# models_full.json yamaha_pdx-11
# models_full.json ydp_103_r_2012__vray
# models_full.json yellow_cheesecake
# models_full.json yellow_side_chair
# models_full.json yuanforce_cat_a
# models_full.json yuanforce_turtle
# models_full.json zeitraum_morph_bar_max2010
# models_full.json zenblocks
# models_full.json zhaochaxie_mode
# models_full.json zippo
# models_full.json zuiho_microscope_2010
# models_special.json b04_db_apps_tech_08_03_counter_top
# models_special.json b05_db_apps_tech_08_09_counter_top
# models_special.json cloth_1meter_square
# models_special.json cloth_square
# models_special.json dishwasher_4_counter_top
# models_special.json floating_counter_top_counter_top
# models_special.json fluid_receptacle1m_round
# models_special.json fluid_receptacle1x1
# models_special.json fluid_receptacle1x2
# models_special.json new_ramp
# models_special.json prim_capsule
# models_special.json prim_cone
# models_special.json prim_cube
# models_special.json prim_cyl
# models_special.json prim_sphere
# models_special.json ramp_scene_max
# models_special.json ramp_with_platform
# models_special.json spider
# models_special.json stairs_one
# models_special.json stairs_two
# models_flex.json bowl
# models_flex.json cone
# models_flex.json cube
# models_flex.json cylinder
# models_flex.json dumbbell
# models_flex.json octahedron
# models_flex.json pentagon
# models_flex.json pipe
# models_flex.json platonic
# models_flex.json pyramid
# models_flex.json sphere
# models_flex.json torus
# models_flex.json triangular_prism

# %% [markdown]
# Now let's add some objects to the scene, starting with a table:

# %%
table_stats = {
    "name" : "small_table_green_marble",
    "id" : c.get_unique_id(),
    "position" : {"x" : 0.0, "y" : 0.0, "z" : 0},
    "rotation" : {"x" : 0, "y" : 0, "z" : 0},
    "scale" : {"x" : 1.5, "y" : 1.2, "z" : 1.5},
    "color" : None,
    "material" : None,
    "mass" : 2000,
    "dynamic_friction" : 0.45,
    "static_friction" : 0.48,
    "bounciness" : 0.0,
    "set_kinematic" : False,
    "use_gravity" : True
}
table_bounds = add_tdw_object(c, **table_stats)

# %% [markdown]
# Take a moment to look at the output you get. It has the boundary information of the object you added, including its width, height, depth, x value of the left and right corners, y value of the top and bottom corners, z value of the front and back corners, and the coordinations of all corners

# %%
table_bounds
# Out:
# {'left': -0.8583490252494812,
#  'right': 0.857244074344635,
#  'top': 1.0799124240875244,
#  'bottom': 0.008413001894950867,
#  'front': 0.568520724773407,
#  'back': -0.5684612393379211,
#  'width': 1.7155930995941162,
#  'height': 1.0714994668960571,
#  'depth': 1.1369819641113281,
#  'corners': [[-0.8583490252494812, 1.0799124240875244, -0.5684612393379211],
#   [-0.8583490252494812, 1.0799124240875244, 0.568520724773407],
#   [-0.8583490252494812, 0.008413001894950867, -0.5684612393379211],
#   [-0.8583490252494812, 0.008413001894950867, 0.568520724773407],
#   [0.857244074344635, 1.0799124240875244, -0.5684612393379211],
#   [0.857244074344635, 1.0799124240875244, 0.568520724773407],
#   [0.857244074344635, 0.008413001894950867, -0.5684612393379211],
#   [0.857244074344635, 0.008413001894950867, 0.568520724773407]]}

# %% [markdown]
# You can remove the table using the command below (uncomment and run it to see how it works then run the cell above again before continueing):

# %%
# c.communicate([
#     {"$type": "destroy_object", "id": table_stats["id"]},
#     {"$type": "send_rigidbodies", "frequency": "never"}
# ])
# Out:
# [b'\x00\x00\x00\x07']

# %% [markdown]
# You can also teleport the object and rotate it after adding

# %%
c.communicate(
    [    
        {
            "$type": "teleport_object",
            "position": {"x": 0, "y": 1, "z": 0},
            "id": table_stats["id"]
        },
        {
            "$type": "rotate_object_to",
            "rotation": {"w": 1, "x": 0, "y": 0, "z": 0},
            "id": table_stats["id"]
        }
    ]
)
# Out:
# [b'\x00\x00\x00\n']

# %% [markdown]
# If you set the position such that the table ends up in the air, you see if does not fall down. That's because the simulation is not running. You can use the command below to run the simulation for a certain number of frames:

# %%
n_frames = 50
for i in range(n_frames):
    c.communicate([])

# %% [markdown]
# Now let's add more objects. We can start by placing a box on top of the table. You can extract the y value of table top from table_bounds["top"]

# %%
station_stats = {
    "name" : "iron_box",
    "id" : c.get_unique_id(),
    "position" : {"x" : 0, "y" : table_bounds["top"], "z" : 0.15},
    "rotation" : {"x" : 0, "y" : 0, "z" : 0},
    "scale" : {"x" : 2.0, "y" : 0.7, "z" : 4.0},
    "color" : None,
    "material" : "parquet_wood_red_cedar",
    "mass" : 1000,
    "dynamic_friction" : 0.15,
    "static_friction" : 0.18,
    "bounciness" : 0.0,
    "set_kinematic" : False,
    "use_gravity" : True,
}
station_bounds = add_tdw_object(c, **station_stats)

# %% [markdown]
# Let's add a ramp on top

# %%
ramp_stats = {
    "name" : "ramp_with_platform_weld",
    "id" : c.get_unique_id(),
    "position" : {"x" : 0, "y" : station_bounds["top"], "z" : 0.15},
    "rotation" : {"x" : 0, "y" : -90, "z" : 0},
    "scale" : {"x" : 0.2, "y" : 0.4, "z" : 0.4},
    "color" : {"r" : 0.7, "g" : 0.7, "b" : 1},
    "mass" : 1000,
    "dynamic_friction" : 0.15,
    "static_friction" : 0.18,
    "bounciness" : 0.8,
    "set_kinematic" : False,
    "use_gravity" : True,
    "library" : "models_full.json"
}
ramp_bounds = add_tdw_object(c, **ramp_stats)

# %% [markdown]
# Now let's place walls on the left and right side (we don't want any object that slides to fall from the side)

# %%
left_wall_stats = {
    "name" : "iron_box",
    "id" : c.get_unique_id(),
    "position" : {"x" : -0.42, "y" : table_bounds["top"], "z" : 0.05},
    "rotation" : {"x" : 0, "y" : 0, "z" : 0},
    "scale" : {"x" : 0.1, "y" : 2.5, "z" : 3.0},
    "color" : None,
    "material" : "parquet_wood_red_cedar",
    "mass" : 1000,
    "dynamic_friction" : 0.15,
    "static_friction" : 0.18,
    "bounciness" : 0.8,
    "set_kinematic" : False,
    "use_gravity" : True
}
left_wall_bounds = add_tdw_object(c, **left_wall_stats)

right_wall_stats = {
    "name" : "iron_box",
    "id" : c.get_unique_id(),
    "position" : {"x" : 0.42, "y" : table_bounds["top"], "z" : 0.05},
    "rotation" : {"x" : 0, "y" : 0, "z" : 0},
    "scale" : {"x" : 0.1, "y" : 2.5, "z" : 3.0},
    "color" : None,
    "material" : "parquet_wood_red_cedar",
    "mass" : 1000,
    "dynamic_friction" : 0.15,
    "static_friction" : 0.18,
    "bounciness" : 0.8,
    "set_kinematic" : False,
    "use_gravity" : True
}
right_wall_bounds = add_tdw_object(c, **right_wall_stats)

# %% [markdown]
# Now let's place a ball on top of the ramp. The ball is going to slide down yet so we don't run the simulation

# %%
ball_stats = {
    "name" : "prim_sphere",
    "id" : c.get_unique_id(),
    "position" : {"x" : 0, "y" : ramp_bounds["top"] + 0.1, "z" : 0.25},
    "rotation" : {"x" : 0, "y" : 0, "z" : 0},
    "scale" : {"x" : 0.06, "y" : 0.06, "z" : 0.06},
    "color" : {"r" : 0.8, "g" : 0, "b" : 0},
    "mass" : 2.0,
    "dynamic_friction" : 0.15,
    "static_friction" : 0.18,
    "bounciness" : 0.8,
    "set_kinematic" : False,
    "use_gravity" : True,
    "library" : "models_special.json"
}
ball_bounds = add_tdw_object(c, **ball_stats)

# %% [markdown]
# At this point, you can also attach a recorder to your camera to capture the video of the motion

# %%
capture = ImageCapture(path=images_dir, avatar_ids=["a"])
c.add_ons.append(capture)

# %% [markdown]
# But it's no fun if the ball just falls down. We all know how it's gonna move. It will be more fun if a force with random direction and amplitude is applied to the ball.

# %%
force_vector = {"x": np.random.uniform(-0.001, 0.001), "y": 0, "z": np.random.uniform(-0.0005, 0)}
print("force vector: {}".format(force_vector))
c.communicate(
    {
        "$type": "apply_force_to_object",
        "id": ball_stats["id"],
        "force": force_vector,
    }
)

# Run the simulation for 3 seconds
start_time = time.time()
while time.time() - start_time < 3:
    c.communicate([])
# Out:
# force vector: {'x': -0.00027734723652325904, 'y': 0, 'z': -0.0003517335731325273}

# %% [markdown]
# Take a look into the images folder. You can see a picture of every frame saved in the folder. If you want to attch frames to each other to make a video, check out
#
# https://github.com/threedworld-mit/tdw/blob/master/Documentation/lessons/video/overview.md

# %% [markdown]
# Finally, run the command below to terminate the simulation

# %%
c.communicate({"$type": "terminate"})
# Out:
# [b'\x10\x00\x00\x00quit\x00\x00\x06\x00\x08\x00\x07\x00\x06\x00\x00\x00\x00\x00\x00\x01',
#  b'\x18\x00\x00\x00imag\x00\x00\x0e\x00\x18\x00\x04\x00\x08\x00\x0c\x00\x10\x00\x14\x00\x0e\x00\x00\x00(\x00\x00\x00\x10\x00\x00\x00\xe8\x03\x00\x00\xe8\x03\x00\x00 \x00\x00\x00\x0f\x00\x00\x00SensorContainer\x00\x01\x00\x00\x00a\x00\x00\x00\x01\x00\x00\x00\x10\x00\x00\x00\x00\x00\n\x00\x0c\x00\x00\x00\x08\x00\x07\x00\n\x00\x00\x00\x00\x00\x00\x02\x04\x00\x00\x00\xcb>\x01\x00\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x02\x00\x00\x01\x00\x01\x00\x00\xff\xc0\x00\x11\x08\x03\xe8\x03\xe8\x03\x00"\x00\x01\x11\x01\x02\x11\x01\xff\xdb\x00C\x00\x08\x06\x06\x07\x06\x05\x08\x07\x07\x07\t\t\x08\n\x0c\x14\r\x0c\x0b\x0b\x0c\x19\x12\x13\x0f\x14\x1d\x1a\x1f\x1e\x1d\x1a\x1c\x1c $.\' ",#\x1c\x1c(7),01444\x1f\'9=82<.342\xff\xdb\x00C\x01\t\t\t\x0c\x0b\x0c\x18\r\r\x182!\x1c!22222222222222222222222222222222222222222222222222\xff\xc4\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\xff\xc4\x00\xb5\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd1\xf0$3br\x82\t\n\x16\x17\x18\x19\x1a%&\'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz\t\n\x0b\xff\xc4\x00\xb5\x11\x00\x02\x01\x02\x04\x04\x03\x04\x07\x05\x04\x04\x00\x01\x02w\x00\x01\x02\x03\x11\x04\x05!1\x06\x12AQ\x07aq\x13"2\x81\x08\x14B\x91\xa1\xb1\xc1\t#3R\xf0\x15br\xd1\n\x16$4\xe1%\xf1\x17\x18\x19\x1a&\'()*56789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz?\x00(\xa6\xe6\x9c\x8a\xce\xea\x8a2\xccp\x00\xeeh\x19\xdc\xd8\x0b}[J\x81\xe7\x869\x08]\xa7p\xce\x08\xe0\xe3\xd3\xa5V\xbb\xf0\x9d\xbb\xa8x\x1d\xe0\xdd\xc8\x07\xe6_\xf1\xfdkWE\xd3E\x95\x9a@\xee0\xa0\xbc\xaex\x03\xd6\x98u\xd8u+\x96\xf2\x18yQ\x9d\xa8=\xbdi\x88\xe3u\r\x12\xf3NO2E\x0f\x16q\xe6\' }}+6\xbdJ9\x12H\xda)T<n0\xca\xc3 \x8a\xe3<C\xe1\xe6\xd3\x1f\xed\x16\xc1\x9e\xcd\xcf^\xa63\xe8}\xbd\r!\x98\x14\x94f\x8cP\x01IKI@\t\xd7\x8ai\x14\xfaN\xb4\x00\x82\x8a1\x8a)\x0c(\xa34P\x02\xd2\x1a(\xa0\x02\x8a(\xa0\x04\xc5-\x19\xa2\x80\x0c\xd0h\xa2\x80\n)(\xcd\x00.(\xa2\x8a\x00(4RP\x02\xd1IFh\x00\xa2\x97\xb5\x14\x00f\x90\xd1\x9a(\x00\xa5\xa4\xa34\x00R\xd2f\x96\x80\x0c\xd2\x1a3E\x00-\x14\x99\xa34\x00QE\x14\x00\xb9\xa4\xa34P\x01KI\x9a\\\xd0\x02QK\xde\x8a\x00))sI@\x05-&is@\tE(\xa3\xa0\xa0\x034\x94\xb9\xa4\xa0\x02\x96\x934\xb9\x14\x00\x94\xb4\n(\x00\xcd%\x19\xe2\x8a\x00)i3K\x9a\x00JZ(\xcd\x00\x19\xa4\xa3\xb5\x1d(\x01h\xa4\xcd/\xd2\x80\x12\x96\x8a3@\x06i)M&h\x01h\xa4\xcd-\x00\x14QE\x00\x04\xd1Hh\xa0\x05\xa2\x8a(\x00\xa2\x8a(\x00&\x8aJ\\\xd0\x01E\x14P\x01E\x14g\xbd\x006F\xe3\x15\x16)I\xc9\xcd.(\x10\n(\xa5\xa0\x04\x14\xeaLR\x8a\x00(\xa3\xbd-\x00\x14QE\x00\x00Q\xde\x96\x9ah\x01h\xefIE\x00)\xa4\xa2\x8a\x00:\xd1E\x14\x00QIFh\x00\xebA\xa2\x83@\x06h\xa4\xa2\x80\x14\xd2b\x8a(\x00\xa2\x8a3@\x0b@\xa4\xa2\x80\x0c\xd1E\x18\xa0\x0b\x15\xad\xe1\xdbaq\xacDXeb\x06C\xf8t\xfdH\xac\xbcWM\xe1\x08\xf35\xd3\xe3\x90\xaa?<\xff\x00\x854\x06\xdf\x88\xae~\xc7\xe1\xb9B\x9cIt\xe2!\x8f\xee\xf5?\xe1\xf8\xd7\to<\x96\xb2\x89#8#\xa8\xf5\xafJ\xd5t1\xac\xe9v\xf1\t\xbc\xa9#%\xd4\x91\x90s\xd8\xd7\x03\xa8\xe97Ze\xc1\x86\xe62\xa7\xf8Xta\xea\r\x0cH\xe94\xcdM.\xa2\x04\x1c7q\xe9[\x91J\x92F\xd1J\xa1\xe3q\x86R2\x08\xae\x13C\xb6\x9a}EV6*\xa0ns\xed]V\xa12\xe9\x1ac]I f\'l1\x9e\xae\xdf\xe0(\x03\x98\xf1\x16\x82t\xa9\xc4\xd0e\xad%?)\xee\x ...
#  b'\x00\x00\x00\x92']

# %% [markdown]
# The ball is going to roll down as soon as we run the simulation. But what do we want to do with the ball? One option is to show them a video of the ball rolling down half way and ask them to click where they think the ball is going to hit the table.
